# %% [markdown]
# # Augment data with inverted image

# %%
from pathlib import Path
from common import path
from data_augmentations import invert
from data_augmentations import augment

path
# Out:
# PosixPath('/tmp/ramdisk/handwritten')

# %%
path.ls()
# Out:
# [PosixPath('/tmp/ramdisk/handwritten/Validation'),
#  PosixPath('/tmp/ramdisk/handwritten/Train')]

# %%
augment(path, invert)

# %%
def print_file_name(file):
    print(file)

augment(path, print_file_name)
# Out:
# /tmp/ramdisk/handwritten/Validation/Z/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/Z/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/Z/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/Z/2.jpg
# /tmp/ramdisk/handwritten/Validation/Z/1.jpg
# /tmp/ramdisk/handwritten/Validation/Z/0.jpg
# /tmp/ramdisk/handwritten/Validation/Y/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/Y/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/Y/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/Y/2.jpg
# /tmp/ramdisk/handwritten/Validation/Y/1.jpg
# /tmp/ramdisk/handwritten/Validation/Y/0.jpg
# /tmp/ramdisk/handwritten/Validation/X/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/X/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/X/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/X/2.jpg
# /tmp/ramdisk/handwritten/Validation/X/1.jpg
# /tmp/ramdisk/handwritten/Validation/X/0.jpg
# /tmp/ramdisk/handwritten/Validation/W/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/W/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/W/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/W/2.jpg
# /tmp/ramdisk/handwritten/Validation/W/1.jpg
# /tmp/ramdisk/handwritten/Validation/W/0.jpg
# /tmp/ramdisk/handwritten/Validation/V/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/V/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/V/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/V/2.jpg
# /tmp/ramdisk/handwritten/Validation/V/1.jpg
# /tmp/ramdisk/handwritten/Validation/V/0.jpg
# /tmp/ramdisk/handwritten/Validation/U/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/U/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/U/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/U/2.jpg
# /tmp/ramdisk/handwritten/Validation/U/1.jpg
# /tmp/ramdisk/handwritten/Validation/U/0.jpg
# /tmp/ramdisk/handwritten/Validation/T/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/T/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/T/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/T/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/T/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/T/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/S/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/S/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/S/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/S/2.jpg
# /tmp/ramdisk/handwritten/Validation/S/1.jpg
# /tmp/ramdisk/handwritten/Validation/S/0.jpg
# /tmp/ramdisk/handwritten/Validation/R/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/R/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/R/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/R/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/R/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/R/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/Q/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/Q/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/Q/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/Q/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/Q/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/Q/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/P/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/P/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/P/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/P/2.jpg
# /tmp/ramdisk/handwritten/Validation/P/1.jpg
# /tmp/ramdisk/handwritten/Validation/P/0.jpg
# /tmp/ramdisk/handwritten/Validation/N/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/N/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/N/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/N/2.jpg
# /tmp/ramdisk/handwritten/Validation/N/1.jpg
# /tmp/ramdisk/handwritten/Validation/N/0.jpg
# /tmp/ramdisk/handwritten/Validation/M/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/M/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/M/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/M/2.jpg
# /tmp/ramdisk/handwritten/Validation/M/1.jpg
# /tmp/ramdisk/handwritten/Validation/M/0.jpg
# /tmp/ramdisk/handwritten/Validation/L/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/L/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/L/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/L/2.jpg
# /tmp/ramdisk/handwritten/Validation/L/1.jpg
# /tmp/ramdisk/handwritten/Validation/L/0.jpg
# /tmp/ramdisk/handwritten/Validation/K/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/K/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/K/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/K/2.jpg
# /tmp/ramdisk/handwritten/Validation/K/1.jpg
# /tmp/ramdisk/handwritten/Validation/K/0.jpg
# /tmp/ramdisk/handwritten/Validation/J/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/J/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/J/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/J/2.jpg
# /tmp/ramdisk/handwritten/Validation/J/1.jpg
# /tmp/ramdisk/handwritten/Validation/J/0.jpg
# /tmp/ramdisk/handwritten/Validation/I/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/I/invert_1_10.jpg
# /tmp/ramdisk/handwritten/Validation/I/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Validation/I/_1_3.jpg
# /tmp/ramdisk/handwritten/Validation/I/_1_10.jpg
# /tmp/ramdisk/handwritten/Validation/I/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/H/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/H/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/H/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/H/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/H/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/H/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/G/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/G/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/G/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/G/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/G/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/G/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/F/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/F/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/F/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/F/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/F/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/F/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/E/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/E/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/E/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/E/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/E/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/E/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/D/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/D/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/D/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/D/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/D/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/D/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/C/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/C/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/C/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/C/2.jpg
# /tmp/ramdisk/handwritten/Validation/C/1.jpg
# /tmp/ramdisk/handwritten/Validation/C/0.jpg
# /tmp/ramdisk/handwritten/Validation/B/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/B/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/B/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/B/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/B/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/B/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/A/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/A/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/A/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/A/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/A/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/A/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/@/invert__0_326835.png
# /tmp/ramdisk/handwritten/Validation/@/invert__0_38222.png
# /tmp/ramdisk/handwritten/Validation/@/invert__0_585764.png
# /tmp/ramdisk/handwritten/Validation/@/__0_585764.png
# /tmp/ramdisk/handwritten/Validation/@/__0_38222.png
# /tmp/ramdisk/handwritten/Validation/@/__0_326835.png
# /tmp/ramdisk/handwritten/Validation/9/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/9/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/9/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/9/2.jpg
# /tmp/ramdisk/handwritten/Validation/9/1.jpg
# /tmp/ramdisk/handwritten/Validation/9/0.jpg
# /tmp/ramdisk/handwritten/Validation/8/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/8/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/8/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/8/2.jpg
# /tmp/ramdisk/handwritten/Validation/8/1.jpg
# /tmp/ramdisk/handwritten/Validation/8/0.jpg
# /tmp/ramdisk/handwritten/Validation/7/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/7/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/7/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/7/2.jpg
# /tmp/ramdisk/handwritten/Validation/7/1.jpg
# /tmp/ramdisk/handwritten/Validation/7/0.jpg
# /tmp/ramdisk/handwritten/Validation/6/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/6/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/6/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/6/2.jpg
# /tmp/ramdisk/handwritten/Validation/6/1.jpg
# /tmp/ramdisk/handwritten/Validation/6/0.jpg
# /tmp/ramdisk/handwritten/Validation/5/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/5/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/5/invert3.jpg
# /tmp/ramdisk/handwritten/Validation/5/3.jpg
# /tmp/ramdisk/handwritten/Validation/5/1.jpg
# /tmp/ramdisk/handwritten/Validation/5/0.jpg
# /tmp/ramdisk/handwritten/Validation/4/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/4/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/4/invert3.jpg
# /tmp/ramdisk/handwritten/Validation/4/3.jpg
# /tmp/ramdisk/handwritten/Validation/4/2.jpg
# /tmp/ramdisk/handwritten/Validation/4/0.jpg
# /tmp/ramdisk/handwritten/Validation/3/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/3/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/3/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/3/2.jpg
# /tmp/ramdisk/handwritten/Validation/3/1.jpg
# /tmp/ramdisk/handwritten/Validation/3/0.jpg
# /tmp/ramdisk/handwritten/Validation/2/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/2/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/2/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/2/2.jpg
# /tmp/ramdisk/handwritten/Validation/2/1.jpg
# /tmp/ramdisk/handwritten/Validation/2/0.jpg
# /tmp/ramdisk/handwritten/Validation/1/invert0.jpg
# /tmp/ramdisk/handwritten/Validation/1/invert1.jpg
# /tmp/ramdisk/handwritten/Validation/1/invert2.jpg
# /tmp/ramdisk/handwritten/Validation/1/2.jpg
# /tmp/ramdisk/handwritten/Validation/1/1.jpg
# /tmp/ramdisk/handwritten/Validation/1/0.jpg
# /tmp/ramdisk/handwritten/Validation/0/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/0/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/0/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/0/_1_2.jpg
# /tmp/ramdisk/handwritten/Validation/0/_1_1.jpg
# /tmp/ramdisk/handwritten/Validation/0/_1_0.jpg
# /tmp/ramdisk/handwritten/Validation/&/invert__0_1218973.png
# /tmp/ramdisk/handwritten/Validation/&/invert__0_1394069.png
# /tmp/ramdisk/handwritten/Validation/&/invert__0_1751754.png
# /tmp/ramdisk/handwritten/Validation/&/__0_1751754.png
# /tmp/ramdisk/handwritten/Validation/&/__0_1394069.png
# /tmp/ramdisk/handwritten/Validation/&/__0_1218973.png
# /tmp/ramdisk/handwritten/Validation/$/invert__0_784023.png
# /tmp/ramdisk/handwritten/Validation/$/invert__0_944426.png
# /tmp/ramdisk/handwritten/Validation/$/invert__0_962200.png
# /tmp/ramdisk/handwritten/Validation/$/__0_962200.png
# /tmp/ramdisk/handwritten/Validation/$/__0_944426.png
# /tmp/ramdisk/handwritten/Validation/$/__0_784023.png
# /tmp/ramdisk/handwritten/Validation/#/invert__0_121440.png
# /tmp/ramdisk/handwritten/Validation/#/invert__0_142135.png
# /tmp/ramdisk/handwritten/Validation/#/invert__0_487085.png
# /tmp/ramdisk/handwritten/Validation/#/__0_487085.png
# /tmp/ramdisk/handwritten/Validation/#/__0_142135.png
# /tmp/ramdisk/handwritten/Validation/#/__0_121440.png
# /tmp/ramdisk/handwritten/Train/Z/invert1.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert10.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert2.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert3.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert4.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert5.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert6.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert7.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert8.jpg
# /tmp/ramdisk/handwritten/Train/Z/invert9.jpg
# /tmp/ramdisk/handwritten/Train/Z/9.jpg
# /tmp/ramdisk/handwritten/Train/Z/8.jpg
# /tmp/ramdisk/handwritten/Train/Z/7.jpg
# /tmp/ramdisk/handwritten/Train/Z/6.jpg
# /tmp/ramdisk/handwritten/Train/Z/5.jpg
# /tmp/ramdisk/handwritten/Train/Z/4.jpg
# /tmp/ramdisk/handwritten/Train/Z/3.jpg
# /tmp/ramdisk/handwritten/Train/Z/2.jpg
# /tmp/ramdisk/handwritten/Train/Z/10.jpg
# /tmp/ramdisk/handwritten/Train/Z/1.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert0.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert1.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert2.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert3.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert4.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert5.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert6.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert7.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert8.jpg
# /tmp/ramdisk/handwritten/Train/Y/invert9.jpg
# /tmp/ramdisk/handwritten/Train/Y/9.jpg
# /tmp/ramdisk/handwritten/Train/Y/8.jpg
# /tmp/ramdisk/handwritten/Train/Y/7.jpg
# /tmp/ramdisk/handwritten/Train/Y/6.jpg
# /tmp/ramdisk/handwritten/Train/Y/5.jpg
# /tmp/ramdisk/handwritten/Train/Y/4.jpg
# /tmp/ramdisk/handwritten/Train/Y/3.jpg
# /tmp/ramdisk/handwritten/Train/Y/2.jpg
# /tmp/ramdisk/handwritten/Train/Y/1.jpg
# /tmp/ramdisk/handwritten/Train/Y/0.jpg
# /tmp/ramdisk/handwritten/Train/X/invert0.jpg
# /tmp/ramdisk/handwritten/Train/X/invert1.jpg
# /tmp/ramdisk/handwritten/Train/X/invert2.jpg
# /tmp/ramdisk/handwritten/Train/X/invert3.jpg
# /tmp/ramdisk/handwritten/Train/X/invert4.jpg
# /tmp/ramdisk/handwritten/Train/X/invert5.jpg
# /tmp/ramdisk/handwritten/Train/X/invert6.jpg
# /tmp/ramdisk/handwritten/Train/X/invert7.jpg
# /tmp/ramdisk/handwritten/Train/X/invert8.jpg
# /tmp/ramdisk/handwritten/Train/X/invert9.jpg
# /tmp/ramdisk/handwritten/Train/X/9.jpg
# /tmp/ramdisk/handwritten/Train/X/8.jpg
# /tmp/ramdisk/handwritten/Train/X/7.jpg
# /tmp/ramdisk/handwritten/Train/X/6.jpg
# /tmp/ramdisk/handwritten/Train/X/5.jpg
# /tmp/ramdisk/handwritten/Train/X/4.jpg
# /tmp/ramdisk/handwritten/Train/X/3.jpg
# /tmp/ramdisk/handwritten/Train/X/2.jpg
# /tmp/ramdisk/handwritten/Train/X/1.jpg
# /tmp/ramdisk/handwritten/Train/X/0.jpg
# /tmp/ramdisk/handwritten/Train/W/invert0.jpg
# /tmp/ramdisk/handwritten/Train/W/invert1.jpg
# /tmp/ramdisk/handwritten/Train/W/invert2.jpg
# /tmp/ramdisk/handwritten/Train/W/invert3.jpg
# /tmp/ramdisk/handwritten/Train/W/invert4.jpg
# /tmp/ramdisk/handwritten/Train/W/invert5.jpg
# /tmp/ramdisk/handwritten/Train/W/invert6.jpg
# /tmp/ramdisk/handwritten/Train/W/invert7.jpg
# /tmp/ramdisk/handwritten/Train/W/invert8.jpg
# /tmp/ramdisk/handwritten/Train/W/invert9.jpg
# /tmp/ramdisk/handwritten/Train/W/9.jpg
# /tmp/ramdisk/handwritten/Train/W/8.jpg
# /tmp/ramdisk/handwritten/Train/W/7.jpg
# /tmp/ramdisk/handwritten/Train/W/6.jpg
# /tmp/ramdisk/handwritten/Train/W/5.jpg
# /tmp/ramdisk/handwritten/Train/W/4.jpg
# /tmp/ramdisk/handwritten/Train/W/3.jpg
# /tmp/ramdisk/handwritten/Train/W/2.jpg
# /tmp/ramdisk/handwritten/Train/W/1.jpg
# /tmp/ramdisk/handwritten/Train/W/0.jpg
# /tmp/ramdisk/handwritten/Train/V/invert0.jpg
# /tmp/ramdisk/handwritten/Train/V/invert1.jpg
# /tmp/ramdisk/handwritten/Train/V/invert2.jpg
# /tmp/ramdisk/handwritten/Train/V/invert3.jpg
# /tmp/ramdisk/handwritten/Train/V/invert4.jpg
# /tmp/ramdisk/handwritten/Train/V/invert5.jpg
# /tmp/ramdisk/handwritten/Train/V/invert6.jpg
# /tmp/ramdisk/handwritten/Train/V/invert7.jpg
# /tmp/ramdisk/handwritten/Train/V/invert8.jpg
# /tmp/ramdisk/handwritten/Train/V/invert9.jpg
# /tmp/ramdisk/handwritten/Train/V/9.jpg
# /tmp/ramdisk/handwritten/Train/V/8.jpg
# /tmp/ramdisk/handwritten/Train/V/7.jpg
# /tmp/ramdisk/handwritten/Train/V/6.jpg
# /tmp/ramdisk/handwritten/Train/V/5.jpg
# /tmp/ramdisk/handwritten/Train/V/4.jpg
# /tmp/ramdisk/handwritten/Train/V/3.jpg
# /tmp/ramdisk/handwritten/Train/V/2.jpg
# /tmp/ramdisk/handwritten/Train/V/1.jpg
# /tmp/ramdisk/handwritten/Train/V/0.jpg
# /tmp/ramdisk/handwritten/Train/U/invert0.jpg
# /tmp/ramdisk/handwritten/Train/U/invert1.jpg
# /tmp/ramdisk/handwritten/Train/U/invert2.jpg
# /tmp/ramdisk/handwritten/Train/U/invert3.jpg
# /tmp/ramdisk/handwritten/Train/U/invert4.jpg
# /tmp/ramdisk/handwritten/Train/U/invert5.jpg
# /tmp/ramdisk/handwritten/Train/U/invert6.jpg
# /tmp/ramdisk/handwritten/Train/U/invert7.jpg
# /tmp/ramdisk/handwritten/Train/U/invert8.jpg
# /tmp/ramdisk/handwritten/Train/U/invert9.jpg
# /tmp/ramdisk/handwritten/Train/U/9.jpg
# /tmp/ramdisk/handwritten/Train/U/8.jpg
# /tmp/ramdisk/handwritten/Train/U/7.jpg
# /tmp/ramdisk/handwritten/Train/U/6.jpg
# /tmp/ramdisk/handwritten/Train/U/5.jpg
# /tmp/ramdisk/handwritten/Train/U/4.jpg
# /tmp/ramdisk/handwritten/Train/U/3.jpg
# /tmp/ramdisk/handwritten/Train/U/2.jpg
# /tmp/ramdisk/handwritten/Train/U/1.jpg
# /tmp/ramdisk/handwritten/Train/U/0.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/T/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/T/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/S/invert0.jpg
# /tmp/ramdisk/handwritten/Train/S/invert1.jpg
# /tmp/ramdisk/handwritten/Train/S/invert2.jpg
# /tmp/ramdisk/handwritten/Train/S/invert3.jpg
# /tmp/ramdisk/handwritten/Train/S/invert4.jpg
# /tmp/ramdisk/handwritten/Train/S/invert5.jpg
# /tmp/ramdisk/handwritten/Train/S/invert6.jpg
# /tmp/ramdisk/handwritten/Train/S/invert7.jpg
# /tmp/ramdisk/handwritten/Train/S/invert8.jpg
# /tmp/ramdisk/handwritten/Train/S/invert9.jpg
# /tmp/ramdisk/handwritten/Train/S/9.jpg
# /tmp/ramdisk/handwritten/Train/S/8.jpg
# /tmp/ramdisk/handwritten/Train/S/7.jpg
# /tmp/ramdisk/handwritten/Train/S/6.jpg
# /tmp/ramdisk/handwritten/Train/S/5.jpg
# /tmp/ramdisk/handwritten/Train/S/4.jpg
# /tmp/ramdisk/handwritten/Train/S/3.jpg
# /tmp/ramdisk/handwritten/Train/S/2.jpg
# /tmp/ramdisk/handwritten/Train/S/1.jpg
# /tmp/ramdisk/handwritten/Train/S/0.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/R/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/R/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/Q/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/Q/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/P/invert0.jpg
# /tmp/ramdisk/handwritten/Train/P/invert1.jpg
# /tmp/ramdisk/handwritten/Train/P/invert2.jpg
# /tmp/ramdisk/handwritten/Train/P/invert3.jpg
# /tmp/ramdisk/handwritten/Train/P/invert4.jpg
# /tmp/ramdisk/handwritten/Train/P/invert5.jpg
# /tmp/ramdisk/handwritten/Train/P/invert6.jpg
# /tmp/ramdisk/handwritten/Train/P/invert7.jpg
# /tmp/ramdisk/handwritten/Train/P/invert8.jpg
# /tmp/ramdisk/handwritten/Train/P/invert9.jpg
# /tmp/ramdisk/handwritten/Train/P/9.jpg
# /tmp/ramdisk/handwritten/Train/P/8.jpg
# /tmp/ramdisk/handwritten/Train/P/7.jpg
# /tmp/ramdisk/handwritten/Train/P/6.jpg
# /tmp/ramdisk/handwritten/Train/P/5.jpg
# /tmp/ramdisk/handwritten/Train/P/4.jpg
# /tmp/ramdisk/handwritten/Train/P/3.jpg
# /tmp/ramdisk/handwritten/Train/P/2.jpg
# /tmp/ramdisk/handwritten/Train/P/1.jpg
# /tmp/ramdisk/handwritten/Train/P/0.jpg
# /tmp/ramdisk/handwritten/Train/N/invert0.jpg
# /tmp/ramdisk/handwritten/Train/N/invert1.jpg
# /tmp/ramdisk/handwritten/Train/N/invert2.jpg
# /tmp/ramdisk/handwritten/Train/N/invert3.jpg
# /tmp/ramdisk/handwritten/Train/N/invert4.jpg
# /tmp/ramdisk/handwritten/Train/N/invert5.jpg
# /tmp/ramdisk/handwritten/Train/N/invert6.jpg
# /tmp/ramdisk/handwritten/Train/N/invert7.jpg
# /tmp/ramdisk/handwritten/Train/N/invert8.jpg
# /tmp/ramdisk/handwritten/Train/N/invert9.jpg
# /tmp/ramdisk/handwritten/Train/N/9.jpg
# /tmp/ramdisk/handwritten/Train/N/8.jpg
# /tmp/ramdisk/handwritten/Train/N/7.jpg
# /tmp/ramdisk/handwritten/Train/N/6.jpg
# /tmp/ramdisk/handwritten/Train/N/5.jpg
# /tmp/ramdisk/handwritten/Train/N/4.jpg
# /tmp/ramdisk/handwritten/Train/N/3.jpg
# /tmp/ramdisk/handwritten/Train/N/2.jpg
# /tmp/ramdisk/handwritten/Train/N/1.jpg
# /tmp/ramdisk/handwritten/Train/N/0.jpg
# /tmp/ramdisk/handwritten/Train/M/invert0.jpg
# /tmp/ramdisk/handwritten/Train/M/invert1.jpg
# /tmp/ramdisk/handwritten/Train/M/invert2.jpg
# /tmp/ramdisk/handwritten/Train/M/invert3.jpg
# /tmp/ramdisk/handwritten/Train/M/invert4.jpg
# /tmp/ramdisk/handwritten/Train/M/invert5.jpg
# /tmp/ramdisk/handwritten/Train/M/invert6.jpg
# /tmp/ramdisk/handwritten/Train/M/invert7.jpg
# /tmp/ramdisk/handwritten/Train/M/invert8.jpg
# /tmp/ramdisk/handwritten/Train/M/invert9.jpg
# /tmp/ramdisk/handwritten/Train/M/9.jpg
# /tmp/ramdisk/handwritten/Train/M/8.jpg
# /tmp/ramdisk/handwritten/Train/M/7.jpg
# /tmp/ramdisk/handwritten/Train/M/6.jpg
# /tmp/ramdisk/handwritten/Train/M/5.jpg
# /tmp/ramdisk/handwritten/Train/M/4.jpg
# /tmp/ramdisk/handwritten/Train/M/3.jpg
# /tmp/ramdisk/handwritten/Train/M/2.jpg
# /tmp/ramdisk/handwritten/Train/M/1.jpg
# /tmp/ramdisk/handwritten/Train/M/0.jpg
# /tmp/ramdisk/handwritten/Train/L/invert0.jpg
# /tmp/ramdisk/handwritten/Train/L/invert1.jpg
# /tmp/ramdisk/handwritten/Train/L/invert2.jpg
# /tmp/ramdisk/handwritten/Train/L/invert3.jpg
# /tmp/ramdisk/handwritten/Train/L/invert4.jpg
# /tmp/ramdisk/handwritten/Train/L/invert5.jpg
# /tmp/ramdisk/handwritten/Train/L/invert6.jpg
# /tmp/ramdisk/handwritten/Train/L/invert7.jpg
# /tmp/ramdisk/handwritten/Train/L/invert8.jpg
# /tmp/ramdisk/handwritten/Train/L/invert9.jpg
# /tmp/ramdisk/handwritten/Train/L/9.jpg
# /tmp/ramdisk/handwritten/Train/L/8.jpg
# /tmp/ramdisk/handwritten/Train/L/7.jpg
# /tmp/ramdisk/handwritten/Train/L/6.jpg
# /tmp/ramdisk/handwritten/Train/L/5.jpg
# /tmp/ramdisk/handwritten/Train/L/4.jpg
# /tmp/ramdisk/handwritten/Train/L/3.jpg
# /tmp/ramdisk/handwritten/Train/L/2.jpg
# /tmp/ramdisk/handwritten/Train/L/1.jpg
# /tmp/ramdisk/handwritten/Train/L/0.jpg
# /tmp/ramdisk/handwritten/Train/K/invert0.jpg
# /tmp/ramdisk/handwritten/Train/K/invert1.jpg
# /tmp/ramdisk/handwritten/Train/K/invert2.jpg
# /tmp/ramdisk/handwritten/Train/K/invert3.jpg
# /tmp/ramdisk/handwritten/Train/K/invert4.jpg
# /tmp/ramdisk/handwritten/Train/K/invert5.jpg
# /tmp/ramdisk/handwritten/Train/K/invert6.jpg
# /tmp/ramdisk/handwritten/Train/K/invert7.jpg
# /tmp/ramdisk/handwritten/Train/K/invert8.jpg
# /tmp/ramdisk/handwritten/Train/K/invert9.jpg
# /tmp/ramdisk/handwritten/Train/K/9.jpg
# /tmp/ramdisk/handwritten/Train/K/8.jpg
# /tmp/ramdisk/handwritten/Train/K/7.jpg
# /tmp/ramdisk/handwritten/Train/K/6.jpg
# /tmp/ramdisk/handwritten/Train/K/5.jpg
# /tmp/ramdisk/handwritten/Train/K/4.jpg
# /tmp/ramdisk/handwritten/Train/K/3.jpg
# /tmp/ramdisk/handwritten/Train/K/2.jpg
# /tmp/ramdisk/handwritten/Train/K/1.jpg
# /tmp/ramdisk/handwritten/Train/K/0.jpg
# /tmp/ramdisk/handwritten/Train/J/invert0.jpg
# /tmp/ramdisk/handwritten/Train/J/invert1.jpg
# /tmp/ramdisk/handwritten/Train/J/invert2.jpg
# /tmp/ramdisk/handwritten/Train/J/invert3.jpg
# /tmp/ramdisk/handwritten/Train/J/invert4.jpg
# /tmp/ramdisk/handwritten/Train/J/invert5.jpg
# /tmp/ramdisk/handwritten/Train/J/invert6.jpg
# /tmp/ramdisk/handwritten/Train/J/invert7.jpg
# /tmp/ramdisk/handwritten/Train/J/invert8.jpg
# /tmp/ramdisk/handwritten/Train/J/invert9.jpg
# /tmp/ramdisk/handwritten/Train/J/9.jpg
# /tmp/ramdisk/handwritten/Train/J/8.jpg
# /tmp/ramdisk/handwritten/Train/J/7.jpg
# /tmp/ramdisk/handwritten/Train/J/6.jpg
# /tmp/ramdisk/handwritten/Train/J/5.jpg
# /tmp/ramdisk/handwritten/Train/J/4.jpg
# /tmp/ramdisk/handwritten/Train/J/3.jpg
# /tmp/ramdisk/handwritten/Train/J/2.jpg
# /tmp/ramdisk/handwritten/Train/J/1.jpg
# /tmp/ramdisk/handwritten/Train/J/0.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_11.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_13.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_16.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_17.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/I/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_17.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_16.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_13.jpg
# /tmp/ramdisk/handwritten/Train/I/_1_11.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/H/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/H/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/G/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/G/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/F/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/F/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/E/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/E/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/D/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/D/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/C/invert0.jpg
# /tmp/ramdisk/handwritten/Train/C/invert1.jpg
# /tmp/ramdisk/handwritten/Train/C/invert2.jpg
# /tmp/ramdisk/handwritten/Train/C/invert3.jpg
# /tmp/ramdisk/handwritten/Train/C/invert4.jpg
# /tmp/ramdisk/handwritten/Train/C/invert5.jpg
# /tmp/ramdisk/handwritten/Train/C/invert6.jpg
# /tmp/ramdisk/handwritten/Train/C/invert7.jpg
# /tmp/ramdisk/handwritten/Train/C/invert8.jpg
# /tmp/ramdisk/handwritten/Train/C/invert9.jpg
# /tmp/ramdisk/handwritten/Train/C/9.jpg
# /tmp/ramdisk/handwritten/Train/C/8.jpg
# /tmp/ramdisk/handwritten/Train/C/7.jpg
# /tmp/ramdisk/handwritten/Train/C/6.jpg
# /tmp/ramdisk/handwritten/Train/C/5.jpg
# /tmp/ramdisk/handwritten/Train/C/4.jpg
# /tmp/ramdisk/handwritten/Train/C/3.jpg
# /tmp/ramdisk/handwritten/Train/C/2.jpg
# /tmp/ramdisk/handwritten/Train/C/1.jpg
# /tmp/ramdisk/handwritten/Train/C/0.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/B/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/B/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/A/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/A/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/@/invert___0_2818202.png
# /tmp/ramdisk/handwritten/Train/@/invert___0_3481265.png
# /tmp/ramdisk/handwritten/Train/@/invert___1_3707877.png
# /tmp/ramdisk/handwritten/Train/@/invert___1_8467948.png
# /tmp/ramdisk/handwritten/Train/@/invert___2_180518.png
# /tmp/ramdisk/handwritten/Train/@/invert___2_7171966.png
# /tmp/ramdisk/handwritten/Train/@/invert___3_2220935.png
# /tmp/ramdisk/handwritten/Train/@/invert___3_3419739.png
# /tmp/ramdisk/handwritten/Train/@/invert___4_3480720.png
# /tmp/ramdisk/handwritten/Train/@/invert___4_7767080.png
# /tmp/ramdisk/handwritten/Train/@/___4_7767080.png
# /tmp/ramdisk/handwritten/Train/@/___4_3480720.png
# /tmp/ramdisk/handwritten/Train/@/___3_3419739.png
# /tmp/ramdisk/handwritten/Train/@/___3_2220935.png
# /tmp/ramdisk/handwritten/Train/@/___2_7171966.png
# /tmp/ramdisk/handwritten/Train/@/___2_180518.png
# /tmp/ramdisk/handwritten/Train/@/___1_8467948.png
# /tmp/ramdisk/handwritten/Train/@/___1_3707877.png
# /tmp/ramdisk/handwritten/Train/@/___0_3481265.png
# /tmp/ramdisk/handwritten/Train/@/___0_2818202.png
# /tmp/ramdisk/handwritten/Train/9/invert0.jpg
# /tmp/ramdisk/handwritten/Train/9/invert1.jpg
# /tmp/ramdisk/handwritten/Train/9/invert2.jpg
# /tmp/ramdisk/handwritten/Train/9/invert3.jpg
# /tmp/ramdisk/handwritten/Train/9/invert4.jpg
# /tmp/ramdisk/handwritten/Train/9/invert5.jpg
# /tmp/ramdisk/handwritten/Train/9/invert6.jpg
# /tmp/ramdisk/handwritten/Train/9/invert7.jpg
# /tmp/ramdisk/handwritten/Train/9/invert8.jpg
# /tmp/ramdisk/handwritten/Train/9/invert9.jpg
# /tmp/ramdisk/handwritten/Train/9/9.jpg
# /tmp/ramdisk/handwritten/Train/9/8.jpg
# /tmp/ramdisk/handwritten/Train/9/7.jpg
# /tmp/ramdisk/handwritten/Train/9/6.jpg
# /tmp/ramdisk/handwritten/Train/9/5.jpg
# /tmp/ramdisk/handwritten/Train/9/4.jpg
# /tmp/ramdisk/handwritten/Train/9/3.jpg
# /tmp/ramdisk/handwritten/Train/9/2.jpg
# /tmp/ramdisk/handwritten/Train/9/1.jpg
# /tmp/ramdisk/handwritten/Train/9/0.jpg
# /tmp/ramdisk/handwritten/Train/8/invert0.jpg
# /tmp/ramdisk/handwritten/Train/8/invert1.jpg
# /tmp/ramdisk/handwritten/Train/8/invert2.jpg
# /tmp/ramdisk/handwritten/Train/8/invert3.jpg
# /tmp/ramdisk/handwritten/Train/8/invert4.jpg
# /tmp/ramdisk/handwritten/Train/8/invert5.jpg
# /tmp/ramdisk/handwritten/Train/8/invert6.jpg
# /tmp/ramdisk/handwritten/Train/8/invert7.jpg
# /tmp/ramdisk/handwritten/Train/8/invert8.jpg
# /tmp/ramdisk/handwritten/Train/8/invert9.jpg
# /tmp/ramdisk/handwritten/Train/8/9.jpg
# /tmp/ramdisk/handwritten/Train/8/8.jpg
# /tmp/ramdisk/handwritten/Train/8/7.jpg
# /tmp/ramdisk/handwritten/Train/8/6.jpg
# /tmp/ramdisk/handwritten/Train/8/5.jpg
# /tmp/ramdisk/handwritten/Train/8/4.jpg
# /tmp/ramdisk/handwritten/Train/8/3.jpg
# /tmp/ramdisk/handwritten/Train/8/2.jpg
# /tmp/ramdisk/handwritten/Train/8/1.jpg
# /tmp/ramdisk/handwritten/Train/8/0.jpg
# /tmp/ramdisk/handwritten/Train/7/invert0.jpg
# /tmp/ramdisk/handwritten/Train/7/invert1.jpg
# /tmp/ramdisk/handwritten/Train/7/invert2.jpg
# /tmp/ramdisk/handwritten/Train/7/invert3.jpg
# /tmp/ramdisk/handwritten/Train/7/invert4.jpg
# /tmp/ramdisk/handwritten/Train/7/invert5.jpg
# /tmp/ramdisk/handwritten/Train/7/invert6.jpg
# /tmp/ramdisk/handwritten/Train/7/invert7.jpg
# /tmp/ramdisk/handwritten/Train/7/invert8.jpg
# /tmp/ramdisk/handwritten/Train/7/invert9.jpg
# /tmp/ramdisk/handwritten/Train/7/9.jpg
# /tmp/ramdisk/handwritten/Train/7/8.jpg
# /tmp/ramdisk/handwritten/Train/7/7.jpg
# /tmp/ramdisk/handwritten/Train/7/6.jpg
# /tmp/ramdisk/handwritten/Train/7/5.jpg
# /tmp/ramdisk/handwritten/Train/7/4.jpg
# /tmp/ramdisk/handwritten/Train/7/3.jpg
# /tmp/ramdisk/handwritten/Train/7/2.jpg
# /tmp/ramdisk/handwritten/Train/7/1.jpg
# /tmp/ramdisk/handwritten/Train/7/0.jpg
# /tmp/ramdisk/handwritten/Train/6/invert0.jpg
# /tmp/ramdisk/handwritten/Train/6/invert1.jpg
# /tmp/ramdisk/handwritten/Train/6/invert2.jpg
# /tmp/ramdisk/handwritten/Train/6/invert3.jpg
# /tmp/ramdisk/handwritten/Train/6/invert4.jpg
# /tmp/ramdisk/handwritten/Train/6/invert5.jpg
# /tmp/ramdisk/handwritten/Train/6/invert6.jpg
# /tmp/ramdisk/handwritten/Train/6/invert7.jpg
# /tmp/ramdisk/handwritten/Train/6/invert8.jpg
# /tmp/ramdisk/handwritten/Train/6/invert9.jpg
# /tmp/ramdisk/handwritten/Train/6/9.jpg
# /tmp/ramdisk/handwritten/Train/6/8.jpg
# /tmp/ramdisk/handwritten/Train/6/7.jpg
# /tmp/ramdisk/handwritten/Train/6/6.jpg
# /tmp/ramdisk/handwritten/Train/6/5.jpg
# /tmp/ramdisk/handwritten/Train/6/4.jpg
# /tmp/ramdisk/handwritten/Train/6/3.jpg
# /tmp/ramdisk/handwritten/Train/6/2.jpg
# /tmp/ramdisk/handwritten/Train/6/1.jpg
# /tmp/ramdisk/handwritten/Train/6/0.jpg
# /tmp/ramdisk/handwritten/Train/5/invert0.jpg
# /tmp/ramdisk/handwritten/Train/5/invert1.jpg
# /tmp/ramdisk/handwritten/Train/5/invert10.jpg
# /tmp/ramdisk/handwritten/Train/5/invert11.jpg
# /tmp/ramdisk/handwritten/Train/5/invert12.jpg
# /tmp/ramdisk/handwritten/Train/5/invert3.jpg
# /tmp/ramdisk/handwritten/Train/5/invert5.jpg
# /tmp/ramdisk/handwritten/Train/5/invert6.jpg
# /tmp/ramdisk/handwritten/Train/5/invert8.jpg
# /tmp/ramdisk/handwritten/Train/5/invert9.jpg
# /tmp/ramdisk/handwritten/Train/5/9.jpg
# /tmp/ramdisk/handwritten/Train/5/8.jpg
# /tmp/ramdisk/handwritten/Train/5/6.jpg
# /tmp/ramdisk/handwritten/Train/5/5.jpg
# /tmp/ramdisk/handwritten/Train/5/3.jpg
# /tmp/ramdisk/handwritten/Train/5/12.jpg
# /tmp/ramdisk/handwritten/Train/5/11.jpg
# /tmp/ramdisk/handwritten/Train/5/10.jpg
# /tmp/ramdisk/handwritten/Train/5/1.jpg
# /tmp/ramdisk/handwritten/Train/5/0.jpg
# /tmp/ramdisk/handwritten/Train/4/invert0.jpg
# /tmp/ramdisk/handwritten/Train/4/invert10.jpg
# /tmp/ramdisk/handwritten/Train/4/invert2.jpg
# /tmp/ramdisk/handwritten/Train/4/invert3.jpg
# /tmp/ramdisk/handwritten/Train/4/invert4.jpg
# /tmp/ramdisk/handwritten/Train/4/invert5.jpg
# /tmp/ramdisk/handwritten/Train/4/invert6.jpg
# /tmp/ramdisk/handwritten/Train/4/invert7.jpg
# /tmp/ramdisk/handwritten/Train/4/invert8.jpg
# /tmp/ramdisk/handwritten/Train/4/invert9.jpg
# /tmp/ramdisk/handwritten/Train/4/9.jpg
# /tmp/ramdisk/handwritten/Train/4/8.jpg
# /tmp/ramdisk/handwritten/Train/4/7.jpg
# /tmp/ramdisk/handwritten/Train/4/6.jpg
# /tmp/ramdisk/handwritten/Train/4/5.jpg
# /tmp/ramdisk/handwritten/Train/4/4.jpg
# /tmp/ramdisk/handwritten/Train/4/3.jpg
# /tmp/ramdisk/handwritten/Train/4/2.jpg
# /tmp/ramdisk/handwritten/Train/4/10.jpg
# /tmp/ramdisk/handwritten/Train/4/0.jpg
# /tmp/ramdisk/handwritten/Train/3/invert0.jpg
# /tmp/ramdisk/handwritten/Train/3/invert1.jpg
# /tmp/ramdisk/handwritten/Train/3/invert10.jpg
# /tmp/ramdisk/handwritten/Train/3/invert2.jpg
# /tmp/ramdisk/handwritten/Train/3/invert3.jpg
# /tmp/ramdisk/handwritten/Train/3/invert4.jpg
# /tmp/ramdisk/handwritten/Train/3/invert5.jpg
# /tmp/ramdisk/handwritten/Train/3/invert6.jpg
# /tmp/ramdisk/handwritten/Train/3/invert7.jpg
# /tmp/ramdisk/handwritten/Train/3/invert8.jpg
# /tmp/ramdisk/handwritten/Train/3/invert9.jpg
# /tmp/ramdisk/handwritten/Train/3/9.jpg
# /tmp/ramdisk/handwritten/Train/3/8.jpg
# /tmp/ramdisk/handwritten/Train/3/7.jpg
# /tmp/ramdisk/handwritten/Train/3/6.jpg
# /tmp/ramdisk/handwritten/Train/3/5.jpg
# /tmp/ramdisk/handwritten/Train/3/4.jpg
# /tmp/ramdisk/handwritten/Train/3/3.jpg
# /tmp/ramdisk/handwritten/Train/3/2.jpg
# /tmp/ramdisk/handwritten/Train/3/10.jpg
# /tmp/ramdisk/handwritten/Train/3/1.jpg
# /tmp/ramdisk/handwritten/Train/3/0.jpg
# /tmp/ramdisk/handwritten/Train/2/invert0.jpg
# /tmp/ramdisk/handwritten/Train/2/invert1.jpg
# /tmp/ramdisk/handwritten/Train/2/invert10.jpg
# /tmp/ramdisk/handwritten/Train/2/invert2.jpg
# /tmp/ramdisk/handwritten/Train/2/invert3.jpg
# /tmp/ramdisk/handwritten/Train/2/invert4.jpg
# /tmp/ramdisk/handwritten/Train/2/invert5.jpg
# /tmp/ramdisk/handwritten/Train/2/invert6.jpg
# /tmp/ramdisk/handwritten/Train/2/invert7.jpg
# /tmp/ramdisk/handwritten/Train/2/invert8.jpg
# /tmp/ramdisk/handwritten/Train/2/invert9.jpg
# /tmp/ramdisk/handwritten/Train/2/9.jpg
# /tmp/ramdisk/handwritten/Train/2/8.jpg
# /tmp/ramdisk/handwritten/Train/2/7.jpg
# /tmp/ramdisk/handwritten/Train/2/6.jpg
# /tmp/ramdisk/handwritten/Train/2/5.jpg
# /tmp/ramdisk/handwritten/Train/2/4.jpg
# /tmp/ramdisk/handwritten/Train/2/3.jpg
# /tmp/ramdisk/handwritten/Train/2/2.jpg
# /tmp/ramdisk/handwritten/Train/2/10.jpg
# /tmp/ramdisk/handwritten/Train/2/1.jpg
# /tmp/ramdisk/handwritten/Train/2/0.jpg
# /tmp/ramdisk/handwritten/Train/1/invert0.jpg
# /tmp/ramdisk/handwritten/Train/1/invert1.jpg
# /tmp/ramdisk/handwritten/Train/1/invert10.jpg
# /tmp/ramdisk/handwritten/Train/1/invert2.jpg
# /tmp/ramdisk/handwritten/Train/1/invert4.jpg
# /tmp/ramdisk/handwritten/Train/1/invert5.jpg
# /tmp/ramdisk/handwritten/Train/1/invert6.jpg
# /tmp/ramdisk/handwritten/Train/1/invert7.jpg
# /tmp/ramdisk/handwritten/Train/1/invert8.jpg
# /tmp/ramdisk/handwritten/Train/1/invert9.jpg
# /tmp/ramdisk/handwritten/Train/1/9.jpg
# /tmp/ramdisk/handwritten/Train/1/8.jpg
# /tmp/ramdisk/handwritten/Train/1/7.jpg
# /tmp/ramdisk/handwritten/Train/1/6.jpg
# /tmp/ramdisk/handwritten/Train/1/5.jpg
# /tmp/ramdisk/handwritten/Train/1/4.jpg
# /tmp/ramdisk/handwritten/Train/1/2.jpg
# /tmp/ramdisk/handwritten/Train/1/10.jpg
# /tmp/ramdisk/handwritten/Train/1/1.jpg
# /tmp/ramdisk/handwritten/Train/1/0.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_0.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_1.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_2.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_3.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_4.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_5.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_6.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_7.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_8.jpg
# /tmp/ramdisk/handwritten/Train/0/invert_1_9.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_9.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_8.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_7.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_6.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_5.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_4.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_3.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_2.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_1.jpg
# /tmp/ramdisk/handwritten/Train/0/_1_0.jpg
# /tmp/ramdisk/handwritten/Train/&/invert__8_9331752.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9389422.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9390837.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9422586.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9427814.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9451733.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9460832.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_9511102.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_965683.png
# /tmp/ramdisk/handwritten/Train/&/invert__8_989709.png
# /tmp/ramdisk/handwritten/Train/&/__8_989709.png
# /tmp/ramdisk/handwritten/Train/&/__8_965683.png
# /tmp/ramdisk/handwritten/Train/&/__8_9511102.png
# /tmp/ramdisk/handwritten/Train/&/__8_9460832.png
# /tmp/ramdisk/handwritten/Train/&/__8_9451733.png
# /tmp/ramdisk/handwritten/Train/&/__8_9427814.png
# /tmp/ramdisk/handwritten/Train/&/__8_9422586.png
# /tmp/ramdisk/handwritten/Train/&/__8_9390837.png
# /tmp/ramdisk/handwritten/Train/&/__8_9389422.png
# /tmp/ramdisk/handwritten/Train/&/__8_9331752.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_775340.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_834027.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_843824.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_860182.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_889032.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_919800.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_945916.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_947399.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_962315.png
# /tmp/ramdisk/handwritten/Train/$/invert__9_96768.png
# /tmp/ramdisk/handwritten/Train/$/__9_96768.png
# /tmp/ramdisk/handwritten/Train/$/__9_962315.png
# /tmp/ramdisk/handwritten/Train/$/__9_947399.png
# /tmp/ramdisk/handwritten/Train/$/__9_945916.png
# /tmp/ramdisk/handwritten/Train/$/__9_919800.png
# /tmp/ramdisk/handwritten/Train/$/__9_889032.png
# /tmp/ramdisk/handwritten/Train/$/__9_860182.png
# /tmp/ramdisk/handwritten/Train/$/__9_843824.png
# /tmp/ramdisk/handwritten/Train/$/__9_834027.png
# /tmp/ramdisk/handwritten/Train/$/__9_775340.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_589820.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_637179.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_640091.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_684280.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_685007.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_694105.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_700145.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_72504.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_76570.png
# /tmp/ramdisk/handwritten/Train/#/invert__9_82670.png
# /tmp/ramdisk/handwritten/Train/#/__9_82670.png
# /tmp/ramdisk/handwritten/Train/#/__9_76570.png
# /tmp/ramdisk/handwritten/Train/#/__9_72504.png
# /tmp/ramdisk/handwritten/Train/#/__9_700145.png
# /tmp/ramdisk/handwritten/Train/#/__9_694105.png
# /tmp/ramdisk/handwritten/Train/#/__9_685007.png
# /tmp/ramdisk/handwritten/Train/#/__9_684280.png
# /tmp/ramdisk/handwritten/Train/#/__9_640091.png
# /tmp/ramdisk/handwritten/Train/#/__9_637179.png
# /tmp/ramdisk/handwritten/Train/#/__9_589820.png
